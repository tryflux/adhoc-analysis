# %%
# install required packages

import pandas as pd
from utils.database import query_from_file
import time
import plotly.express as px
import statsmodels.stats.multicomp as ml
# Out:
# /Users/jennamiles/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
#read in pure data from SQL query:\# read in the starling transacitons 
start = time.time()
df = query_from_file('pure_txns.sql')
end = time.time()
query_time = end-start
print(f"Query took {query_time:.2f} seconds")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-56e85790781b> in <module>
#       1 #read in pure data from SQL query:\# read in the starling transacitons
#       2 start = time.time()
# ----> 3 df = query_from_file('pure_txns.sql')
#       4 end = time.time()
#       5 query_time = end-start
#
# ~/Documents/GitHub/adhoc-analysis/src/utils/database.py in query_from_file(sql_file, **kwargs)
#      21 def query_from_file(sql_file: str, **kwargs):
#      22     with open(sql_file, 'r') as f:
# ---> 23         return query(f.read(), **kwargs)
#
# ~/Documents/GitHub/adhoc-analysis/src/utils/database.py in query(sql_statement, **kwargs)
#       6
#       7 def query(sql_statement: str, **kwargs):
# ----> 8     with open(f'{os.environ["PROJECTROOT"]}/.credentials', 'r') as credentials:
#       9         connection = connect(credentials.read())
#      10         cursor = connection.cursor()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jennamiles/Documents/GitHub/adhoc-analysis/.credentials'
